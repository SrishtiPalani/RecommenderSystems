# %%
import requests
import json

import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors

from googleapiclient.discovery import build

# %%
# TODO: update the API key
api_key = 'AIzaSyAKDQxznvsvi0ZovV2Caz2AeL1FJcExD2Q'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
# TODO: record your coordinates for later
# ----
#LA: location="34.011711, -118.249258"; locationRadius="50km"
#CHI:location="41.849250, -87.673263"; locationRadius="40km",
#NYC:location="40.707559, -73.900061"; locationRadius="45km",
#HOU:location="29.745366, -95.362875"; locationRadius="45km",
# ----

def search_videos(youtube, pageToken):
    result = youtube.search().list(
        part="id",
        order="viewCount",
        safeSearch="none",
        regionCode="US",
        pageToken=pageToken,
        type="video",
        maxResults=50,
        location="33.599379, -112.118219", #TODO: update the location based on Google Maps
        locationRadius="40km", #TODO: update the radius based on Google Maps
        publishedAfter="2020-01-09T00:00:00Z", #TODO: update the year (i.e., 2019 or 2020)
        publishedBefore="2020-11-09T00:00:00Z" #TODO: update the year (i.e., 2019 or 2020)
    ).execute()
    return result

# %%
#TODO: use this to test that coordinates are working. MAKE SURE TO REDUCE maxResults TO 5!
res = search_videos(youtube, None)

# %%
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'SGrwyTJCX6fEMFvBtl6G_72qgAA',
#  'nextPageToken': 'CAUQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 69129, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'Vsn-LOw3nmoPOYearY5iaz9iVCw',
#    'id': {'kind': 'youtube#video', 'videoId': 'D4RD_86nAMA'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3yoX1HXKw_NSxBWorqGOS9Xa6yU',
#    'id': {'kind': 'youtube#video', 'videoId': 'MN3IImU-4j8'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5zEbGYf6j3tueYf3hLOkOZEa3bU',
#    'id': {'kind': 'youtube#video', 'videoId': 'O78go7LsSCE'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'JvRj7LUmjV3X0oz1sZbsjEqiDhA',
#    'id': {'kind': 'youtube#video', 'videoId': 'n7ZxEQ7i8J4'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0BFUSvu0u22prH-3FUN4FAKOczk',
#    'id': {'kind': 'youtube#video', 'videoId': 'UBiQFgx4giM'}}]}

# %%
def get_video_byID(youtube, videoID):
    result = youtube.videos().list(
        part="id,snippet,contentDetails,statistics,topicDetails",
        id=videoID
    ).execute()
    return result

# %%
pageToken = None

#TODO: Use either pre or post and update the value in the function.
# videos_pre = []
videos_post = []


for x in range(100):
    print("starting round ", x)
    if pageToken != False:
        videoIDs = search_videos(youtube, pageToken)
        print("searched")
        
        if len(videoIDs["items"]) == 0:
            print("no more!")
            break
        
        pageToken = videoIDs["nextPageToken"]
        print("pageToken is ", pageToken)
        
        for item in videoIDs["items"]:
            videoId = item["id"]["videoId"]
            video = get_video_byID(youtube, videoId)
            print(videoId)
            if len(video["items"]) == 0:
                continue
            if "publishedAt" in video_snippet:
                videos_post.append(video["items"][0]) # TODO: update this accordingly
            else:
                print("corrupt ID")
# Out:
# starting round  0
# searched
# pageToken is  CDIQAA
# D4RD_86nAMA
# MN3IImU-4j8
# O78go7LsSCE
# n7ZxEQ7i8J4
# UBiQFgx4giM
# IiRubAMgzAs
# -rRZtR78U0E
# r7LZ7coodjA
# asnBqlBY0lk
# bkbIfW8vojY
# HjIvhme25ks
# KhhU_Ch65YQ
# hWOZGN9Osvs
# wICo6ub9pkQ
# uVoxWd0v0xM
# nERo8TNXDtc
# k4xz0jeEdlM
# b6HW2kIYZHM
# zYWhByGKhvg
# 0BEatvRcAGs
# NHB-gJ4BfBE
# U6avKKINkwg
# PPwYC9Dafh8
# 48BSlRlGXtA
# P-l02pP0U1Y
# xDuRv5YbBlg
# pcluIZHWZZM
# TeQjBt2JSgo
# ppZ8NSGsKHI
# S3ha-k3r_sk
# Iwb5mLF_Duc
# l4xRhBLDdTE
# zFVbUoL1syA
# q6se2lGrxhI
# QF9spw4TO6Q
# VsFMui2Oxwk
# ko3tWAnYkTw
# R_DJ9gmeaxM
# KzRhcjOG1es
# QH6RxEVrwgE
# TNwzckJ4W60
# 9wn3G5sbQMk
# ZbNJnpxm34E
# cIjtVTArVTE
# -7CvgyX2FfY
# 7lrVwE4jxZ4
# c7PwWRH4gLk
# qEjG-qyY5Ho
# Z7knk-DsLrs
# TH6N_vnzY_Q
# starting round  1
# searched
# pageToken is  CGQQAA
# 1J3_cqPewqg
# Zbs9HOr-aB4
# rD9wKPba0Nk
# zAhlE237_JE
# H6MuBqWvWhQ
# o0MokCLmFrg
# cOhoFv3U4Tg
# Jcqu-zvqBrs
# 4Xz4fC2iwoU
# OEh2eaWNDJI
# Blu5cFUgXUI
# lRZWDqAEWvE
# aGOsjjedUIg
# ...

# %%
#TODO: update pre or post to check the total number returned
len(videos_post)
# Out:
# 500

# %%
# TODO: dump each portion as a backup, change the name accordingly
with open('ytData_PHA2019_446.json', 'w') as outfile:
    json.dump(videos_pre, outfile)

# %%
# TODO: check if dumped correctly by checking the length, use the same name as above
with open('ytData_PHA2019_446.json') as f:
    yt_data = json.load(f)

# %%
len(yt_data)
# Out:
# 446

# %%
videos_full = videos_pre + videos_post

# %%
len(videos_full)
# Out:
# 1017

# %%
for vid in videos_full:
    vid["city"] = "HOU" #TODO: update the abbreviation

# %%
videos_full[500]
# Out:
# {'kind': 'youtube#video',
#  'etag': 'XpcSe45MMVY_W6W1BOkix4qxPNk',
#  'id': 'Vmg1_jNcAfM',
#  'snippet': {'publishedAt': '2020-07-08T02:59:39Z',
#   'channelId': 'UCYHApapZYNwGcgJO7iMIaDw',
#   'title': 'What My Daughter Told Me',
#   'description': 'My daughter Aaryn told me, “I’m just glad to be alive.” I am so happy we only have to pick out crutches instead of a casket.\n\nSUBSCRIBE\nhttp://bit.ly/2zoGO7y\n\nMORE VIDEOS\nbit.ly/2R5Ohzk\n\nWEBSITE\nRickeySmiley.com\n\nFOLLOW\nFacebook: bit.ly/2Kq30mc\nInstagram: bit.ly/2zmqjc4\nTwitter: bit.ly/2TCMOSy\n\n#RickeySmiley',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Vmg1_jNcAfM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Vmg1_jNcAfM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Vmg1_jNcAfM/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
# ...

# %%
#TODO: update the name accordingly
with open('ytData_HOU.json', 'w') as outfile:
    json.dump(videos_full, outfile)

# %%
with open('ytData_NYC.json') as f:
    yt_data = json.load(f)

# %%
len(yt_data)
# Out:
# 1042
